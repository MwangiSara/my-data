# %%
import pandas #its a module for fetching and analysing data

bank= pandas.read_csv(r"C:\Users\Sarah\Desktop\modcom\class\kindi-sarah\data science\data\bank.csv") #we fetch data usig the function read_csv
bank
# Out:
#       Loan_ID  Gender Married     Education Self_Employed  ApplicantIncome  \
# 0    LP001002    Male      No      Graduate            No             5849
# 1    LP001003    Male     Yes      Graduate            No             4583
# 2    LP001005    Male     Yes      Graduate           Yes             3000
# 3    LP001006    Male     Yes  Not Graduate            No             2583
# 4    LP001008    Male      No      Graduate            No             6000
# ..        ...     ...     ...           ...           ...              ...
# 609  LP002978  Female      No      Graduate            No             2900
# 610  LP002979    Male     Yes      Graduate            No             4106
# 611  LP002983    Male     Yes      Graduate            No             8072
# 612  LP002984    Male     Yes      Graduate            No             7583
# 613  LP002990  Female      No      Graduate           Yes             4583
#
#      CoapplicantIncome  LoanAmount Property_Area Loan_Status
# ...

# %%
bank.head(20)
# Out:
#      Loan_ID  Gender Married     Education Self_Employed  ApplicantIncome  \
# 0   LP001002    Male      No      Graduate            No             5849
# 1   LP001003    Male     Yes      Graduate            No             4583
# 2   LP001005    Male     Yes      Graduate           Yes             3000
# 3   LP001006    Male     Yes  Not Graduate            No             2583
# 4   LP001008    Male      No      Graduate            No             6000
# 5   LP001011    Male     Yes      Graduate           Yes             5417
# 6   LP001013    Male     Yes  Not Graduate            No             2333
# 7   LP001014    Male     Yes      Graduate            No             3036
# 8   LP001018    Male     Yes      Graduate            No             4006
# 9   LP001020    Male     Yes      Graduate            No            12841
# 10  LP001024    Male     Yes      Graduate            No             3200
# 11  LP001027    Male     Yes      Graduate           NaN             2500
# ...

# %%
bank.tail(20) # the fuction head()prints the top rows and tail() prints the bottom/last rows
# Out:
#       Loan_ID  Gender Married     Education Self_Employed  ApplicantIncome  \
# 594  LP002938    Male     Yes      Graduate           Yes            16120
# 595  LP002940    Male      No  Not Graduate            No             3833
# 596  LP002941    Male     Yes  Not Graduate           Yes             6383
# 597  LP002943    Male      No      Graduate            No             2987
# 598  LP002945    Male     Yes      Graduate           Yes             9963
# 599  LP002948    Male     Yes      Graduate            No             5780
# 600  LP002949  Female      No      Graduate           NaN              416
# 601  LP002950    Male     Yes  Not Graduate           NaN             2894
# 602  LP002953    Male     Yes      Graduate            No             5703
# 603  LP002958    Male      No      Graduate            No             3676
# 604  LP002959  Female     Yes      Graduate            No            12000
# ...

# %%
Kindi={
    "Teacher":["Sarah","Mwangi"],
    "Student":["Allan","Vincent"]
}
kindi_table=pandas.DataFrame(Kindi)
kindi_table
# Out:
#   Teacher  Student
# 0   Sarah    Allan
# 1  Mwangi  Vincent

# %%
sarah={
    "age":[21],
    "height":[5.11]
}
sarah_table=pandas.DataFrame(sarah)
sarah_table
# Out:
#    age  height
# 0   21    5.11

# %%
bank
# Out:
#       Loan_ID  Gender Married     Education Self_Employed  ApplicantIncome  \
# 0    LP001002    Male      No      Graduate            No             5849
# 1    LP001003    Male     Yes      Graduate            No             4583
# 2    LP001005    Male     Yes      Graduate           Yes             3000
# 3    LP001006    Male     Yes  Not Graduate            No             2583
# 4    LP001008    Male      No      Graduate            No             6000
# ..        ...     ...     ...           ...           ...              ...
# 609  LP002978  Female      No      Graduate            No             2900
# 610  LP002979    Male     Yes      Graduate            No             4106
# 611  LP002983    Male     Yes      Graduate            No             8072
# 612  LP002984    Male     Yes      Graduate            No             7583
# 613  LP002990  Female      No      Graduate           Yes             4583
#
#      CoapplicantIncome  LoanAmount Property_Area Loan_Status
# ...

# %%
#accessing Colums/series
bank["Gender"]
# Out:
# 0        Male
# 1        Male
# 2        Male
# 3        Male
# 4        Male
#         ...
# 609    Female
# 610      Male
# 611      Male
# 612      Male
# 613    Female
# Name: Gender, Length: 614, dtype: object

# %%
#accessing more than 1 columns
bank["Education"]
# Out:
# 0          Graduate
# 1          Graduate
# 2          Graduate
# 3      Not Graduate
# 4          Graduate
#            ...
# 609        Graduate
# 610        Graduate
# 611        Graduate
# 612        Graduate
# 613        Graduate
# Name: Education, Length: 614, dtype: object

# %%
#first we have to clean our dataset. 
#we have to check if the dataset has any empty cells(rows or columns)
bank.isnull()
#get the sum of total null cells
bank.isnull().sum()
# Out:
# Loan_ID               0
# Gender                0
# Married               0
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
#adding unknown to the null cells
bank["Self_Employed"].fillna('unknown',inplace=True) #fillna() fills the empty cells with the unknown
bank.isnull().sum() #isnull() checks the empty/null cells in the dataset
# Out:
# C:\Users\Sarah\AppData\Local\Temp\ipykernel_15532\1179833721.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   bank["Self_Employed"].fillna('unknown',inplace=True) #fillna() fills the empty cells with the unknown
# Loan_ID               0
# Gender                0
# Married               0
# Education             0
# Self_Employed         0
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
#quantitative data(continous) we can get the sum, mean, mode, average, and median with columns
mean_loan=bank["LoanAmount"].mean()
mean_loan
bank["LoanAmount"].fillna(mean_loan,inplace=True)
bank.isnull().sum()
# Out:
# C:\Users\Sarah\AppData\Local\Temp\ipykernel_15532\4149974239.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   bank["LoanAmount"].fillna(mean_loan,inplace=True)
# Loan_ID              0
# Gender               0
# Married              0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Property_Area        0
# Loan_Status          0
# dtype: int64

# %%
bank.describe() #the function describe  gives us a simple analysis of our dataset quantitative columns
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount
# count       614.000000         614.000000  614.000000
# mean       5403.459283        1621.245798  146.412162
# std        6109.041673        2926.248369   84.037468
# min         150.000000           0.000000    9.000000
# 25%        2877.500000           0.000000  100.250000
# 50%        3812.500000        1188.500000  129.000000
# 75%        5795.000000        2297.250000  164.750000
# max       81000.000000       41667.000000  700.000000

# %%
# finding the correlation between columns. we use the function corr()
bank[["ApplicantIncome","CoapplicantIncome","LoanAmount"]].corr() #negative correlation is a relationship btwn 2 variables that move in opposite direction. abd vice verca
# Out:
#                    ApplicantIncome  CoapplicantIncome  LoanAmount
# ApplicantIncome           1.000000          -0.116605    0.565620
# CoapplicantIncome        -0.116605           1.000000    0.187828
# LoanAmount                0.565620           0.187828    1.000000

# %%
#different datatype in our dataset
bank.dtypes
# Out:
# Loan_ID               object
# Gender                object
# Married               object
# Education             object
# Self_Employed         object
# ApplicantIncome        int64
# CoapplicantIncome    float64
# LoanAmount           float64
# Property_Area         object
# Loan_Status           object
# dtype: object

# %%
#finding proportinality of categorical(qualitative) datatypes. we use the function groupby()
bank.groupby('Gender').size()
# Out:
# Gender
# Female    125
# Male      489
# dtype: int64

# %%
bank.groupby('Married').size()
# Out:
# Married
# No     213
# Yes    401
# dtype: int64

# %%
#grouping more than 1 column
bank.groupby(['Gender','Self_Employed']).size()
# Out:
# Gender  Self_Employed
# Female  No                98
#         Yes               19
#         unknown            8
# Male    No               402
#         Yes               63
#         unknown           24
# dtype: int64

# %%
bank.groupby('Property_Area').size().plot(kind="pie",autopct="% 1.1F%%",explode=[0.1,0,0])
#autopct parameter displays the percentage value using string format
#explode highlights or emphasizes key data in a pie chart
# Out:
# <Axes: >

# %%
#pie chart that shows gender
bank.groupby('Gender').size().plot(kind="pie")
#piechart is univariante, that is, we only use one variable/column when ploting
# Out:
# <Axes: >

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.countplot(x=bank["Gender"],palette='Reds') #we are creating a bar graph for the column gender
plt.title("Distribution of gender") # we are giving the graph a title
plt.ylabel("Number of Members") # we are labeling the y axis
# Out:
# C:\Users\Sarah\AppData\Local\Temp\ipykernel_15532\2733133706.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=bank["Gender"],palette='Reds') #we are creating a bar graph for the column gender
# Text(0, 0.5, 'Number of Members')

# %%
#creating countplot() for column Married
sns.countplot(x=bank["Married"]) #countplot() is a univariant plot, just like pie chart
plt.title("Distibution of married members")
plt.ylabel("Number of members")
plt.xlabel("Members")
# Out:
# Text(0.5, 0, 'Members')

# %%
#smarmplot() is a type of scatter plot that is used for representing categorical datatypes. it is bivariante(2 columns/variables) in nature, but it can be multivariante(3 or more columns/variable) when we add a parameter 'hue'
sns.swarmplot(x='Married',y='ApplicantIncome',data=bank,palette='magma',hue='Gender')
# Out:
# c:\Users\Sarah\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\categorical.py:3399: UserWarning: 18.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\Sarah\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\categorical.py:3399: UserWarning: 38.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <Axes: xlabel='Married', ylabel='ApplicantIncome'>
# c:\Users\Sarah\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\categorical.py:3399: UserWarning: 39.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# ...

# %%
#we are geting a swamp visualization
sns.swarmplot(x='Gender',y="ApplicantIncome",data=bank, palette = 'magma', hue= 'Self_Employed')
# Out:
# c:\Users\Sarah\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\categorical.py:3399: UserWarning: 45.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <Axes: xlabel='Gender', ylabel='ApplicantIncome'>
# c:\Users\Sarah\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\categorical.py:3399: UserWarning: 61.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\Sarah\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\categorical.py:3399: UserWarning: 28.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
#barplot() shows the relationship btwn quantitative and qualitative columns/datatypes. it is bivariante and can also be multivariante if we add the parameter 'hue'
sns.barplot(x='Gender',y='LoanAmount',data=bank,palette='magma',hue='Property_Area')
# Out:
# <Axes: xlabel='Gender', ylabel='LoanAmount'>

# %%
sns.barplot(x='Married',y='CoapplicantIncome',data=bank,hue='Education',palette='magma')
# Out:
# <Axes: xlabel='Married', ylabel='CoapplicantIncome'>

# %%
sns.scatterplot(x='LoanAmount',y='ApplicantIncome',data=bank,hue='Gender',palette='magma')
# Out:
# <Axes: xlabel='LoanAmount', ylabel='ApplicantIncome'>
