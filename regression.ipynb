# %%
#data science:
#step 1: data preprocessing - identifying the data types in the dataset
#step 2:dataset exploration- fetch and display our dataset in table format
#step 3: data cleaning - removing null cells
#step 4: data anlysis- we use describe(),groupby() etc to anlyse data
#step 5: EDA or Clustering or regression etc
#step 6: make descision according to our data analysis

# %%
#step 2:dataset exploration- fetch and display our dataset in table format
import pandas
advert=pandas.read_csv(r"C:\Users\Sarah\Desktop\modcom\class\kindi-sarah\data science\data\Advertising.csv")
advert
# Out:
#       No     TV  Radio  Newspaper  Sales
# 0      1  230.1   37.8       69.2   22.1
# 1      2   44.5   39.3       45.1   10.4
# 2      3   17.2   45.9       69.3    9.3
# 3      4  151.5   41.3       58.5   18.5
# 4      5  180.8   10.8       58.4   12.9
# ..   ...    ...    ...        ...    ...
# 195  196   38.2    3.7       13.8    7.6
# 196  197   94.2    4.9        8.1    9.7
# 197  198  177.0    9.3        6.4   12.8
# 198  199  283.6   42.0       66.2   25.5
# 199  200  232.1    8.6        8.7   13.4
#
# [200 rows x 5 columns]

# %%
#step 3: data cleaning - removing null cells
advert.isnull().sum()
# Out:
# No           0
# TV           0
# Radio        0
# Newspaper    0
# Sales        0
# dtype: int64

# %%
#step 4: data anlysis- we use describe(),groupby() etc to anlyse data
advert.describe()
# Out:
#                No          TV       Radio   Newspaper       Sales
# count  200.000000  200.000000  200.000000  200.000000  200.000000
# mean   100.500000  147.042500   23.264000   30.554000   14.022500
# std     57.879185   85.854236   14.846809   21.778621    5.217457
# min      1.000000    0.700000    0.000000    0.300000    1.600000
# 25%     50.750000   74.375000    9.975000   12.750000   10.375000
# 50%    100.500000  149.750000   22.900000   25.750000   12.900000
# 75%    150.250000  218.825000   36.525000   45.100000   17.400000
# max    200.000000  296.400000   49.600000  114.000000   27.000000

# %%
#step 5: regression, we test continous datatypes and the ouptut is a continous datatype.
#we first split our dataset into two:X(fetures/predictors), Y(target/output) 
array=advert.values
array
X=array[0:200,1:4]
X
Y=array[0:200,4:5]
Y
# Out:
# array([[22.1],
#        [10.4],
#        [ 9.3],
#        [18.5],
#        [12.9],
#        [ 7.2],
#        [11.8],
#        [13.2],
#        [ 4.8],
#        [10.6],
#        [ 8.6],
#        [17.4],
#        [ 9.2],
#        [ 9.7],
#        [19. ],
#        [22.4],
#        [12.5],
#        [24.4],
#        [11.3],
#        [14.6],
#        [18. ],
#        [12.5],
#        [ 5.6],
#        [15.5],
#        [ 9.7],
#        [12. ],
#        [15. ],
#        [15.9],
#        [18.9],
#        [10.5],
#        [21.4],
#        [11.9],
#        [ 9.6],
#        [17.4],
#        [ 9.5],
#        [12.8],
#        [25.4],
#        [14.7],
#        [10.1],
#        [21.5],
#        [16.6],
#        [17.1],
#        [20.7],
#        [12.9],
#        [ 8.5],
#        [14.9],
#        [10.6],
#        [23.2],
#        [14.8],
#        [ 9.7],
#        [11.4],
#        [10.7],
#        [22.6],
#        [21.2],
#        [20.2],
#        [23.7],
#        [ 5.5],
#        [13.2],
# ...

# %%
#take our variables X and Y and split them into training set(70%) and testing set(30%)
from sklearn import model_selection
X_test,X_train,Y_test,Y_train=model_selection.train_test_split(X,Y,test_size=0.3,random_state=42) # test_size specifies the proportion of the dataset to be allocatd to the test and train set. we use float btwn 1.0 and 0.0.

# %%
#fit our dataseet to our model , we fit X_train and Y_train.
#we will be using linear regression algorithm
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
#testing our model perfomance using X_test data and Compare the prediction with Y_test data
model_prediction=model.predict(X_test)
model_prediction
# Out:
# array([[19.1556315 ],
#        [15.72918854],
#        [11.30993201],
#        [ 9.4384724 ],
#        [18.35678346],
#        [ 6.68188162],
#        [22.53974021],
#        [ 5.97978856],
#        [10.72148141],
#        [11.02224598],
#        [ 9.90961997],
#        [ 7.22189315],
#        [15.36506196],
#        [17.15828147],
#        [14.59461135],
#        [17.05586361],
#        [15.17164237],
#        [19.85415481],
#        [14.38721708],
#        [21.36600754],
#        [10.86318319],
#        [13.90329788],
#        [ 8.9506207 ],
#        [17.37859171],
#        [ 8.83919827],
#        [15.05558549],
#        [12.87273936],
#        [23.85520699],
#        [12.114329  ],
#        [22.6531695 ],
#        [ 5.95083492],
#        [17.77045641],
#        [22.6372084 ],
#        [19.88811696],
#        [17.97618023],
#        [16.65884648],
#        [12.46887983],
#        [11.35785978],
#        [17.73576083],
#        [14.17424614],
#        [13.28079985],
# ...

# %%
Y_test
# Out:
# array([[15. ],
#        [15.5],
#        [11.9],
#        [ 9.2],
#        [12.8],
#        [ 6.6],
#        [20.7],
#        [ 6.7],
#        [11.2],
#        [ 9.5],
#        [10.7],
#        [ 8.8],
#        [14.9],
#        [17.1],
#        [15.9],
#        [15.9],
#        [15. ],
#        [20.7],
#        [11.7],
#        [21.8],
#        [ 9.3],
#        [14.2],
#        [10.6],
#        [17.3],
#        [ 9.9],
#        [15.2],
#        [13.3],
#        [25.4],
#        [10.8],
#        [24.2],
#        [ 5.6],
#        [19.2],
#        [23.8],
#        [17.4],
#        [17.4],
#        [17.3],
#        [12.9],
#        [11.8],
#        [15.9],
#        [15.5],
#        [12.9],
#        [ 9.6],
#        [20.1],
#        [10.3],
#        [19.8],
#        [11.4],
#        [ 8.6],
#        [15.7],
#        [14.1],
#        [13.2],
#        [ 8. ],
#        [22.1],
#        [25.5],
#        [19. ],
#        [18.3],
#        [15.2],
#        [18. ],
#        [ 8.5],
# ...

# %%
#lets check the accuracy of our algorithm
from sklearn.metrics import r2_score
print("accuracy=",r2_score(model_prediction,Y_test)*100)
# Out:
# accuracy= 86.49681490542294

# %%
expeses=[[50,500,60]]
outcome=model.predict(expeses)
outcome
# Out:
# array([[88.42622115]])

# %%
# Imports Regression Models
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.svm import SVR
from sklearn.linear_model import LinearRegression


# Kotlin Compiler for terminal
# open-jdk
# VS Code Extensition: coderunner, kotlin


# Create an Empty List and append all models, Give the Models an alias Name
# i.e we called KNeighborsRegressor()) alias KNR etc
models = []
models.append(('D Trees', DecisionTreeRegressor()))
models.append(('KNR', KNeighborsRegressor()))
models.append(('LR', LinearRegression()))
models.append(('Support Machines', SVR(gamma = 'auto')))
models.append(('Random Forest', RandomForestRegressor()))
models.append(('Gradient Boosting', GradientBoostingRegressor()))
models.append(('Support Machines', SVR(gamma = 'auto')))

# Import Cross Validation and KFOLD
from sklearn.model_selection import cross_val_score, KFold
# Create a for loop so that each model is tested in turn
for name, model in models:
          # Here we do a 10 split K-FOLD
          kfold = KFold(n_splits = 10, random_state=42, shuffle=True)

          # We get the results for each Fold, Train and Test using the Folds
          cv_results = cross_val_score(model, X_train, Y_train, cv = kfold,
          scoring='r2')

          # Get the average of all Folds for current model in the loop
          print(name, ' Results:= ', cv_results.mean())
# Out:
# D Trees  Results:=  0.7782361093427667
# KNR  Results:=  0.6694624338683317
# LR  Results:=  0.7665416354817435
# c:\Users\Sarah\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\Sarah\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\Sarah\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# ...
